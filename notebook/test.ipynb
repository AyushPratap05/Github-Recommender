# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import importlib
import recommend

importlib.reload(recommend)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# <module 'recommend' from 'c:\\Users\\ayush\\PROJECTS\\Github-Recommender\\recommend.py'>

# %%
from recommend import search_repositories

# %%
results = search_repositories(
    "Find me a Python deep-learning project for image classification."
)

results
# Out:
# [{'name': 'WZMIAOMIAO/deep-learning-for-image-processing',
#   'description': 'deep learning for image processing including classification and object-detection etc.',
#   'language': 'Python',
#   'stars': 26372,
#   'url': 'https://github.com/WZMIAOMIAO/deep-learning-for-image-processing',
#   'similarity': 75.93},
#  {'name': 'aleju/imgaug',
#   'description': 'Image augmentation for machine learning experiments.',
#   'language': 'Python',
#   'stars': 14740,
#   'url': 'https://github.com/aleju/imgaug',
#   'similarity': 65.63},
#  {'name': 'OlafenwaMoses/ImageAI',
#   'description': 'A python library built to empower developers to build applications and systems  with self-contained Computer Vision capabilities',
#   'language': 'Python',
#   'stars': 8882,
#   'url': 'https://github.com/OlafenwaMoses/ImageAI',
#   'similarity': 60.12},
#  {'name': 'tangyudi/Ai-Learn',
# ...

# %%
recommend.detect_language("I want a Python project for detecting fake news")
# Out:
# 'python'

# %%
recommend.detect_language("Find me a React project for building a dashboard")

# %%
results = search_repositories(
    "I want a Python project for detecting fake news"
)

results
# Out:
# [{'name': 'shirosaidev/stocksight',
#   'description': 'Stock market analyzer and predictor using Elasticsearch, Twitter, News headlines and Python natural language processing and sentiment analysis',
#   'language': 'Python',
#   'stars': 2535,
#   'url': 'https://github.com/shirosaidev/stocksight',
#   'similarity': 44.96,
#   'score': 54.96},
#  {'name': 'pymupdf/PyMuPDF',
#   'description': 'PyMuPDF is a high performance Python library for data extraction, analysis, conversion & manipulation of PDF (and other) documents.',
#   'language': 'Python',
#   'stars': 10660,
#   'url': 'https://github.com/pymupdf/PyMuPDF',
#   'similarity': 44.72,
#   'score': 54.72},
#  {'name': 'fossasia/visdom',
#   'description': 'Tool for real-time visualization, monitoring and collaborative analysis of AI/ML experiments and live data. Supports Python, PyTorch/Torch, NumPy, TensorFlow/Keras https://visdom.dev',
#   'language': 'Python',
#   'stars': 10289,
# ...

# %%
results = search_repositories(
    "Find me a machine learning project using Python"
)

results
# Out:
# [{'name': 'ujjwalkarn/DataSciencePython',
#   'description': 'common data analysis and machine learning tasks using python',
#   'language': 'Python',
#   'stars': 5821,
#   'url': 'https://github.com/ujjwalkarn/DataSciencePython',
#   'similarity': 63.81,
#   'score': 73.81},
#  {'name': 'gradio-app/gradio',
#   'description': 'Build and share delightful machine learning apps, all in Python. 🌟 Star to support our work!',
#   'language': 'Python',
#   'stars': 43486,
#   'url': 'https://github.com/gradio-app/gradio',
#   'similarity': 61.16,
#   'score': 71.16},
#  {'name': 'scikit-learn/scikit-learn',
#   'description': 'scikit-learn: machine learning in Python',
#   'language': 'Python',
#   'stars': 67207,
#   'url': 'https://github.com/scikit-learn/scikit-learn',
#   'similarity': 60.33,
#   'score': 70.33},
#  {'name': 'donnemartin/data-science-ipython-notebooks',
# ...

# %%
results = search_repositories(
    "I want a Python project for detecting fake news"
)

results
# Out:
# [{'name': 'shirosaidev/stocksight',
#   'description': 'Stock market analyzer and predictor using Elasticsearch, Twitter, News headlines and Python natural language processing and sentiment analysis',
#   'language': 'Python',
#   'stars': 2535,
#   'url': 'https://github.com/shirosaidev/stocksight',
#   'similarity': 44.96,
#   'score': 54.96},
#  {'name': 'pymupdf/PyMuPDF',
#   'description': 'PyMuPDF is a high performance Python library for data extraction, analysis, conversion & manipulation of PDF (and other) documents.',
#   'language': 'Python',
#   'stars': 10660,
#   'url': 'https://github.com/pymupdf/PyMuPDF',
#   'similarity': 44.72,
#   'score': 54.72},
#  {'name': 'fossasia/visdom',
#   'description': 'Tool for real-time visualization, monitoring and collaborative analysis of AI/ML experiments and live data. Supports Python, PyTorch/Torch, NumPy, TensorFlow/Keras https://visdom.dev',
#   'language': 'Python',
#   'stars': 10289,
# ...

# %%
results = search_repositories(
    "I want a Python project for detecting fake news"
)

results
# Out:
# [{'name': 'shirosaidev/stocksight',
#   'description': 'Stock market analyzer and predictor using Elasticsearch, Twitter, News headlines and Python natural language processing and sentiment analysis',
#   'language': 'Python',
#   'stars': 2535,
#   'url': 'https://github.com/shirosaidev/stocksight',
#   'similarity': 44.96,
#   'keyword_bonus': 2.0,
#   'score': 56.96},
#  {'name': 'pymupdf/PyMuPDF',
#   'description': 'PyMuPDF is a high performance Python library for data extraction, analysis, conversion & manipulation of PDF (and other) documents.',
#   'language': 'Python',
#   'stars': 10660,
#   'url': 'https://github.com/pymupdf/PyMuPDF',
#   'similarity': 44.72,
#   'keyword_bonus': 1.0,
#   'score': 55.72},
#  {'name': 'fossasia/visdom',
#   'description': 'Tool for real-time visualization, monitoring and collaborative analysis of AI/ML experiments and live data. Supports Python, PyTorch/Torch, NumPy, TensorFlow/Keras https://visdom.dev',
#   'language': 'Python',
# ...
