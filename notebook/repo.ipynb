# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\ayush\PROJECTS\Github-Recommender\Data\repositories.csv')
df
# Out:
#                                        name  \
# 0                     tensorflow/tensorflow
# 1                  huggingface/transformers
# 2                microsoft/ML-For-Beginners
# 3                     fighting41love/funNLP
# 4     josephmisiti/awesome-machine-learning
# ..                                      ...
# 456  PacktPublishing/LLM-Engineers-Handbook
# 457                   kelvins/awesome-mlops
# 458                      argilla-io/argilla
# 459                tencentmusic/cube-studio
# 460                    SeldonIO/seldon-core
#
#                                            description   stars  forks  \
# 0    An Open Source Machine Learning Framework for ...  199328  76290
# 1    🤗 Transformers: the model-definition framework...  164954  34483
# 2    12 weeks, 26 lessons, 52 quizzes, classic Mach...   90242  22203
# 3    中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...   82938  15277
# 4    A curated list of awesome Machine Learning fra...   74274  15638
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 461 entries, 0 to 460
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         461 non-null    str
#  1   description  457 non-null    str
#  2   stars        461 non-null    int64
#  3   forks        461 non-null    int64
#  4   language     396 non-null    str
#  5   topics       461 non-null    str
#  6   updated_at   461 non-null    str
#  7   license      390 non-null    str
#  8   url          461 non-null    str
# dtypes: int64(2), str(7)
# memory usage: 32.5 KB

# %%
df.describe()
# Out:
#                stars         forks
# count     461.000000    461.000000
# mean    15056.633406   3286.310195
# std     25408.382229   7326.094726
# min      1179.000000     26.000000
# 25%      4360.000000    630.000000
# 50%      8032.000000   1349.000000
# 75%     17469.000000   3408.000000
# max    368503.000000  76290.000000

# %%
df.isnull().sum()
# Out:
# name            0
# description     4
# stars           0
# forks           0
# language       65
# topics          0
# updated_at      0
# license        71
# url             0
# dtype: int64

# %%
df["language"].value_counts()
# Out:
# language
# Python              172
# Jupyter Notebook     72
# JavaScript           33
# TypeScript           27
# C++                  24
# Go                   14
# HTML                  9
# Java                  6
# Rust                  6
# TeX                   5
# C                     4
# C#                    4
# Shell                 4
# Ruby                  3
# MDX                   3
# PHP                   2
# Scala                 1
# CSS                   1
# Dart                  1
# R                     1
# SCSS                  1
# Astro                 1
# Markdown              1
# MATLAB                1
# Name: count, dtype: int64

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\ayush\PROJECTS\Github-Recommender\Data\repositories.csv')
df
# Out:
#                                        name  \
# 0                     tensorflow/tensorflow
# 1                  huggingface/transformers
# 2                microsoft/ML-For-Beginners
# 3                     fighting41love/funNLP
# 4     josephmisiti/awesome-machine-learning
# ..                                      ...
# 456  PacktPublishing/LLM-Engineers-Handbook
# 457                   kelvins/awesome-mlops
# 458                      argilla-io/argilla
# 459                tencentmusic/cube-studio
# 460                    SeldonIO/seldon-core
#
#                                            description   stars  forks  \
# 0    An Open Source Machine Learning Framework for ...  199328  76290
# 1    🤗 Transformers: the model-definition framework...  164954  34483
# 2    12 weeks, 26 lessons, 52 quizzes, classic Mach...   90242  22203
# 3    中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...   82938  15277
# 4    A curated list of awesome Machine Learning fra...   74274  15638
# ...

# %%
df['readme'].isnull().sum()
# Out:
# np.int64(402)

# %%
(df["readme"] == "").sum()
# Out:
# np.int64(0)

# %%
df["readme"].str.len().describe()
# Out:
# count        59.000000
# mean      40482.813559
# std       90098.356116
# min        1842.000000
# 25%        5356.500000
# 50%        9007.000000
# 75%       28883.000000
# max      505845.000000
# Name: readme, dtype: float64

# %%
df[["name", "readme"]].head(5)
# Out:
#                                     name  \
# 0                  tensorflow/tensorflow
# 1               huggingface/transformers
# 2             microsoft/ML-For-Beginners
# 3                  fighting41love/funNLP
# 4  josephmisiti/awesome-machine-learning
#
#                                               readme
# 0  <div align="center">\n  <img src="https://www....
# 1  <!---\nCopyright 2020 The HuggingFace Team. Al...
# 2  [![GitHub license](https://img.shields.io/gith...
# 3  <center>\n    <img style="border-radius: 0.312...
# 4  # Awesome Machine Learning [![Awesome](https:/...

# %%
print("Empty READMEs:", (df["readme"] == "").sum())
# Out:
# Empty READMEs: 0
